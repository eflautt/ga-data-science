# %% [markdown]
# #Project 4 Solutions

# %% [markdown]
# ###Intro: Write a problem Statement/ Specific Aim for this project

# %% [markdown]
# Answer: Determine if there is an association between graduate school admitance and the prestige of the a student's undergraduate school using data from the UCLA admissions data set

# %% [markdown]
# ###Dataset:  Write up a description of your data and any cleaning that was completed.

# %% [markdown]
# Answer: There were originally 400 applicants in our dataset. There were 3 observations with missing data that were drop from this analysis. This data was collected from XX to XX. GPA ranged from 0-4, while GRE ranged from 200-800. The ordinal variable, prestige (1= highest prestige to 4= lowest prestige) was coverted to a class variable with highest prestige as the reference category.

# %% [markdown]
# ####Provide a table that explains the data by admission status

# %% [markdown]
# Mean (STD) or counts by admission status for each variable
#
# | Not Admitted | Admitted
# ---| ---|---
# GPA | 3.2 (0.3) | 3.8 (0.3)
# GRE | 500 (100) | 700 (100)
# Prestige 1 | 50 | 100
# Prestige 2 | 100 | 50
# Prestige 3 |125 | 25
# Prestige 4 | 200 | 10

# %% [markdown]
# ###Methods: Write up the methods used in your analysis

# %% [markdown]
# Answer: We completed a logistic regression using Statsmodels v. XX. We calculated the probability of being admitted to graduate school given the prestige of the undergraduate school controlling for GRE and GPA. We additionally calculated the predicted probability of each student being admitted to school.

# %% [markdown]
# ### Results: Write up your results

# %% [markdown]
# Students who attended a teir 2 undergraduate school had 0.50 (CI 0.27, 0.94) the odds of being admitted to graduate school compared to students who attend a teir 1 undergraduate school. This decreased further with teir 3 OR=0.26(CI 0.13, 0.52) and teir 4 OR 0.21 (CI 0.09,  0.48) compared to teir 1 schools.

# %% [markdown]
# ####Provide a table or visualization of these results

# %% [markdown]
# <img src='assets/figure1.jpg' height= 50% width= 50%>

# %% [markdown]
# <img src='assets/figure2.jpg' height= 50% width= 50%>

# %% [markdown]
# ###Discussion: Write up your discussion and future steps

# %% [markdown]
# Our findings indicate that students have a higher probability of being admitted to grad school if they attended a prestiguious undergraduate school. Next steps could be exploring differences by field of study. (just 1 example of many options)
