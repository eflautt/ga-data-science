# %% [markdown]
# #Project 1- solutions

# %% [markdown]
# ### Read and evaluate the following problem statement:
# Determine how likely free-tier customers are to covert to paying customers using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user) using Hooli data from Jan-Apr 2015.

# %% [markdown]
# ####1. What is the outcome?

# %% [markdown]
# Answer: likliness of conversion to paid customer

# %% [markdown]
# ####2. What are the predictors/covariates?

# %% [markdown]
# Answer: age, gender, location, profession, days since last log in, and activity score 1 = active user, 0= inactive user

# %% [markdown]
# ####3. What timeframe is this data relevent for?

# %% [markdown]
# Answer: Jan-Apr 2015

# %% [markdown]
# ####4. What is the hypothesis?

# %% [markdown]
# Answer: That customers who were more recently active are more likely to convert to the paid teir

# %% [markdown]
# ### Let's get started with our dataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np

df = pd.read_csv("assets/admissions.csv")
df.head()
# Out:
#    admit  gre   gpa  prestige
# 0      0  380  3.61         3
# 1      1  660  3.67         3
# 2      1  800  4.00         1
# 3      1  640  3.19         4
# 4      0  520  2.93         4

# %% [markdown]
# ####1. create a data dictionary

# %% [markdown]
# Answer: To be completed when the dataset is finalized
#
# Variable | Description | Type of Variable
# ---| ---| ---
# Admit| 0 = not admitted 1 = admitted | categorical
# GRE | GRE score 200-800 | continuous
# GPA | GPA 0-4.0 | continuous
# Prestige | 1= not prestigious 2 = low prestige 3= good prestige 4= high prestige | categorical

# %% [markdown]
#     We would like to explore the association between admittance into grad school and prestige of undergraduate

# %% [markdown]
# ####1. What is the outcome?

# %% [markdown]
# Answer: admittance into grad school

# %% [markdown]
# ####2. What are the predictors/covariates?

# %% [markdown]
# Answer: Prestige, GRE, GPA

# %% [markdown]
# ####3. What timeframe is this data relevent for?

# %% [markdown]
# Answer: Need to look this up

# %% [markdown]
# ####4. What is the hypothesis?

# %% [markdown]
# Answer: Students that attended schools more pretigious undergraduate schools will have higher admissions rates into graduate school.

# %% [markdown]
#     Using the above information, write a well-formed problem statement.

# %% [markdown]
# Problem Statement:
# Determine if there is an association between graduate school admitance and the prestige of the a student's undergraduate school using data from the UCLA admissions data set

# %% [markdown]
# ###Exploratory Analysis Plan

# %% [markdown]
#     Using the lab from a class a guide. Create an exploratory analysis plan.

# %% [markdown]
# ####1. What are the goals of the exploratory analysis?

# %% [markdown]
# Answer:
# 1. determine if there is any missing data
# 2. examine the distributions of the variables to determine if any of the variables need be transformed

# %% [markdown]
# ####2a. What are the assumptions of the distribution of data?

# %% [markdown]
# Answer: normality

# %% [markdown]
# ####2b. How will determine the distribution of your data?

# %% [markdown]
# Answer: histograms

# %% [markdown]
# ####3a. How might outliers impact your analysis?

# %% [markdown]
# Answer: they could skew the associations in the direction of the outlier

# %% [markdown]
# ####3b. How will you test for outliers?

# %% [markdown]
# Answer: box plots are 1 good way

# %% [markdown]
# ####4a. What is colinearity?

# %% [markdown]
# Answer: When two variables are capturing similar variance in the data

# %% [markdown]
# ####4b. How will you test for colinearity?

# %% [markdown]
# Answer: create a correlation matrix

# %% [markdown]
# ####Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis 1 year from now.

# %% [markdown]
# Answer: 1. check for missing data and remove observations with missing 2. check for colinearity 3. check for normal distribution

# %% [markdown]
# #### Bonus Questions:
# 1. Outline your analysis method for predicting your outcome
# 2. Write an alternative problem statement for your dataset
# 3. Articulate the assumptions and risks of the alternative model
